# %% [markdown]
# Plans for yolo model testing
# 1.   Getting yolo to detect anything on a picture.
# 2.   Using a premade dataset to train yolo model to detect stuff on pcb-s.
# 3.   Using it with live cam.
# 4.   Using a premade dataset to start detecting components on a pcb.
# 5.   Creating my own dataset to use with the end components and boards.
# 6.   Using another model to interpret schematics.
# 7.   Using the result to compare the pcb and schematic and say if they match.
# https://yolov8.com/

# %%
conda install conda-forge::ultralytics
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\joona\ylikool\baka\repo\pcb-detector\.conda
#
#   added / updated specs:
#     - conda-forge::ultralytics
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     bottleneck-1.3.7           |  py312he558020_0         131 KB
#     brotli-1.0.9               |       h2bbff1b_8          19 KB
#     brotli-bin-1.0.9           |       h2bbff1b_8          29 KB
#     brotli-python-1.0.9        |  py312hd77b12b_8         346 KB
#     certifi-2024.8.30          |  py312haa95532_0         164 KB
#     charset-normalizer-3.3.2   |     pyhd3eb1b0_0          44 KB
#     contourpy-1.2.0            |  py312h59b6b97_0         200 KB
# ...

# %%
conda install pytorch::pytorch
# Out:
# Channels:
#  - defaults
#  - pytorch
#  - conda-forge
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\joona\ylikool\baka\repo\pcb-detector\.conda
#
#   added / updated specs:
#     - pytorch::pytorch
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     filelock-3.13.1            |  py312haa95532_0          23 KB
#     jinja2-3.1.4               |  py312haa95532_0         349 KB
#     libuv-1.48.0               |       h827c3e9_0         322 KB
#     markupsafe-2.1.3           |  py312h2bbff1b_0          27 KB
#     mpmath-1.3.0               |  py312haa95532_0         989 KB
#     networkx-3.3               |  py312haa95532_0         3.0 MB
#     pytorch-2.5.1              |     py3.12_cpu_0       150.6 MB  pytorch
#     pytorch-mutex-1.0          |              cpu           3 KB  pytorch
# ...

# %%
pip install torch
# Out:
# ...
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------------------------------ --------- 4.7/6.2 MB 23.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 23.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ultralytics 8.3.27 requires opencv-python>=4.6.0, which is not installed.
# ultralytics 8.3.27 requires torchvision>=0.9.0, which is not installed.
# ultralytics 8.3.27 requires ultralytics-thop>=2.0.0, which is not installed.

# %%
pip install cv2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
conda install conda-forge::opencv
# Out:
# Channels:
#  - defaults
#  - conda-forge
#  - pytorch
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge opencv
# Out:
# Channels:
#  - conda-forge
#  - defaults
#  - pytorch
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\joona\ylikool\baka\repo\pcb-detector\.conda
#
#   added / updated specs:
#     - opencv
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cairo-1.16.0               |    h63a05c6_1001         5.2 MB  conda-forge
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
#     gettext-0.22.5             |       h5728263_3          33 KB  conda-forge
#     gettext-tools-0.22.5       |       h5a7288d_3         3.3 MB  conda-forge
#     graphite2-1.3.14           |       hd77b12b_1          91 KB
#     gst-plugins-base-1.22.9    |       h001b923_1         1.9 MB  conda-forge
#     gstreamer-1.22.9           |       hb4038d2_1         1.8 MB  conda-forge
# ...

# %%
import cv2
print(cv2.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import cv2
#       2 print(cv2.__version__)
#
# ImportError: DLL load failed while importing cv2: The specified procedure could not be found.

# %%
from ultralytics import YOLO
model = YOLO("yolov8s.pt") # load the model
results = model.train(data="coco128.yaml", epochs=10)
results = model("./image.png")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from ultralytics import YOLO
#       2 model = YOLO("yolov8s.pt") # load the model
#       3 results = model.train(data="coco128.yaml", epochs=10)
#
# File c:\Users\joona\ylikool\baka\repo\pcb-detector\.conda\Lib\site-packages\ultralytics\__init__.py:11
#       8 if not os.environ.get("OMP_NUM_THREADS"):
#       9     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
# ---> 11 from ultralytics.models import NAS, RTDETR, SAM, YOLO, FastSAM, YOLOWorld
#      12 from ultralytics.utils import ASSETS, SETTINGS
#      13 from ultralytics.utils.checks import check_yolo as checks
#
# File c:\Users\joona\ylikool\baka\repo\pcb-detector\.conda\Lib\site-packages\ultralytics\models\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ...
